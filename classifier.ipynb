# %%
import pandas as pd
from preprocess import transform

# %%
df = pd.read_csv("bigdata2023classification/train.csv")
df
# Out:
#             Id                                              Title  \
# 0       227464  Netflix is coming to cable boxes, and Amazon i...
# 1       244074  Pharrell, Iranian President React to Tehran 'H...
# 2        60707                    Wildlife service seeks comments
# 3        27883  Facebook teams up with Storyful to launch 'FB ...
# 4       169596           Caesars plans US$880 mln New York casino
# ...        ...                                                ...
# 111790   31462  Microsoft requires Office 2013 licensing for s...
# 111791  100821  Smallpox vials missing since 1950s found in la...
# 111792   86181  Scientists May Have Just Discovered the Key to...
# 111793  256423               Justin Bieber to plead guilty to DUI
# 111794  262120  Tracy Morgan upgraded to fair condition after ...
#
#                                                   Content          Label
# 0        if you subscribe to one of three rinky-dink (...  Entertainment
# 1        pharrell, iranian president react to tehran '...  Entertainment
# 2        the u.s. fish and wildlife service has reopen...     Technology
# 3        the very nature of social media means it is o...     Technology
# 4        caesars plans us$880 mln new york casino jul ...       Business
# ...                                                   ...            ...
# 111790   in contrast to the muckle of special licenses...     Technology
# 111791   government workers at a research center near ...         Health
# 111792   harvard scientists may have just unlocked the...         Health
# 111793  justin bieber to plead guilty to duifri, 13 ju...  Entertainment
# 111794   actor and comedian tracy morgan has been upgr...  Entertainment
#
# [111795 rows x 4 columns]

# %%
df = transform(df, ["Title", "Content"])
# Out:
# HTML clean done
# Numbers clean done
# Punctation clean done
# Uppercase clean done
# Tokenize done
# Stopwords clean done
# Rarewords clean done
# Lemmatize done

# %%
df
# Out:
#             Id                             Title  \
# 0       227464          [box, grocery, overlord]
# 1       244074  [iranian, react, tehran, arrest]
# 2        60707                        [wildlife]
# 3        27883          [storyful, fb, newswire]
# 4       169596             [caesar, mln, casino]
# ...        ...                               ...
# 111790   31462                [require, license]
# 111791  100821             [smallpox, vial, lab]
# 111792   86181                    [reverse, age]
# 111793  256423                      [plead, duo]
# 111794  262120             [upgraded, condition]
#
#                                                   Content          Label
# 0       [rinkydink, channelprovided, filtera, netflixr...  Entertainment
# 1       [repent, httptcoxvvaajeyi, harrisongetty, decr...  Entertainment
# 2       [longeared, whitenose, speciesduring, longeare...     Technology
# 3             [inaccuracy, storyfuls, citable, storyfuls]     Technology
# 4       [newsdesk, nbsp, woodbury, parlay, thehectare,...       Business
# ...                                                   ...            ...
# 111790  [endusers, techtarget, rds, citrix, permonth, ...     Technology
# 111791          [supersecure, unaccountedfor, inactivate]         Health
# 111792  [rejuvenate, conjoining, mices, deaging, creb,...         Health
# 111793                 [antidrug, khalil, amir, sharieff]  Entertainment
# 111794          [roper, jonesboro, swerve, plowed, roper]  Entertainment
#
# [111795 rows x 4 columns]
